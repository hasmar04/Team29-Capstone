# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
# !pip install roboflow

# %%
# Copy the Roboflow code snippet here

# %%
# !yolo train task=detect model=yolo11n.pt data="/content/{ADD DATASET NAME}/data.yaml" epochs=30 imgsz=640
